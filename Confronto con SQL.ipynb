# %%
import numpy as np
import pandas as pd

# %%
books= ["La coscienza di zeno", "I Malavoglia", "La simmetria dei desideri"]
rating=[9,8,10]

dict = {'name':books, 'rating': rating }

# %%
df = pd.DataFrame(dict) 
print(df)
# Out:
#                         name  rating
# 0       La coscienza di zeno       9
# 1               I Malavoglia       8
# 2  La simmetria dei desideri      10

# %%
dataset= pd.read_csv("population_by_country_2020.csv")

# %%
dataset.head(11)
# Out:
#    Country (or dependency)  Population (2020) Yearly Change  Net Change  \
# 0                    China         1438207241        0.39 %     5540090
# 1                    India         1377233523        0.99 %    13586631
# 2            United States          330610570        0.59 %     1937734
# 3                Indonesia          272931713        1.07 %     2898047
# 4                 Pakistan          219992900        2.00 %     4327022
# 5                   Brazil          212253150        0.72 %     1509890
# 6                  Nigeria          205052107        2.58 %     5175990
# 7               Bangladesh          164354176        1.01 %     1643222
# 8                   Russia          145922010        0.04 %       62206
# 9                   Mexico          128655589        1.06 %     1357224
# 10                   Japan          126552765       -0.30 %     -383840
#
#     Density (P/Km²)  Land Area (Km²)  Migrants (net) Fert. Rate Med. Age  \
# ...

# %%
dataset=dataset.head(11)

# %%
dataset
# Out:
#    Country (or dependency)  Population (2020) Yearly Change  Net Change  \
# 0                    China         1438207241        0.39 %     5540090
# 1                    India         1377233523        0.99 %    13586631
# 2            United States          330610570        0.59 %     1937734
# 3                Indonesia          272931713        1.07 %     2898047
# 4                 Pakistan          219992900        2.00 %     4327022
# 5                   Brazil          212253150        0.72 %     1509890
# 6                  Nigeria          205052107        2.58 %     5175990
# 7               Bangladesh          164354176        1.01 %     1643222
# 8                   Russia          145922010        0.04 %       62206
# 9                   Mexico          128655589        1.06 %     1357224
# 10                   Japan          126552765       -0.30 %     -383840
#
#     Density (P/Km²)  Land Area (Km²)  Migrants (net) Fert. Rate Med. Age  \
# ...

# %%
dataset.sort_values(by= ["Population (2020)"], ascending=True)
# Out:
#    Country (or dependency)  Population (2020) Yearly Change  Net Change  \
# 10                   Japan          126552765       -0.30 %     -383840
# 9                   Mexico          128655589        1.06 %     1357224
# 8                   Russia          145922010        0.04 %       62206
# 7               Bangladesh          164354176        1.01 %     1643222
# 6                  Nigeria          205052107        2.58 %     5175990
# 5                   Brazil          212253150        0.72 %     1509890
# 4                 Pakistan          219992900        2.00 %     4327022
# 3                Indonesia          272931713        1.07 %     2898047
# 2            United States          330610570        0.59 %     1937734
# 1                    India         1377233523        0.99 %    13586631
# 0                    China         1438207241        0.39 %     5540090
#
#     Density (P/Km²)  Land Area (Km²)  Migrants (net) Fert. Rate Med. Age  \
# ...

# %%
population= dataset["Population (2020)"]
population.max()
# Out:
# 1438207241

# %%
population.sum()
# Out:
# 4621765744

# %%
dataset.plot(kind="scatter", x ="Country (or dependency)" , y= "Population (2020)", s=200, figsize=(20,15))
